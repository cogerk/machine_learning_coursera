# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %% [markdown]
# ![Annotation 2022-05-09 080741.png](attachment:cce872c8-8fd2-40c8-b13a-992c4c2a11cf.png)

# %%
df = pd.DataFrame({'x1': [89, 72, 94, 69], 'x2':[7921, 5184, 8836, 4761], 'y':[96, 74, 87, 78]})

df
# Out:
#    x1    x2   y
# 0  89  7921  96
# 1  72  5184  74
# 2  94  8836  87
# 3  69  4761  78

# %%
x2_range = np.max(df['x2'])-np.min(df['x2'])
x2_range
# Out:
# 4075

# %%
x2_mean = np.mean(df['x2'])
x2_mean
# Out:
# 6675.5

# %%
norm_feat_calc = (df['x2'][3]-x2_mean)/x2_range
norm_feat_calc
# Out:
# -0.4698159509202454

# %%
preprocessing.normalize(df['x2'].to_numpy().reshape(1,-1))
# Out:
# array([[0.57410895, 0.37573296, 0.64042756, 0.3450742 ]])
